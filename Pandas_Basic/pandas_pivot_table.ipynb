# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    554     70   John  January      Q1
# 1  2023-01-02       B   West    230     21   Mary  January      Q1
# 2  2023-01-03       C  North    431     34    Bob  January      Q1
# 3  2023-01-04       D  South    782     42  Alice  January      Q1
# 4  2023-01-05       A   East    709     56   John  January      Q1
# 5  2023-01-06       B   West    190     72   Mary  January      Q1
# 6  2023-01-07       C  North    697     36    Bob  January      Q1
# 7  2023-01-08       D  South    875     44  Alice  January      Q1
# 8  2023-01-09       A   East    942     21   John  January      Q1
# 9  2023-01-10       B   West    751     17   Mary  January      Q1
# 10 2023-01-11       C  North    223     14    Bob  January      Q1
# 11 2023-01-12       D  South    323     72  Alice  January      Q1
# 12 2023-01-13       A   East    837     58   John  January      Q1
# 13 2023-01-14       B   West    458     76   Mary  January      Q1
# 14 2023-01-15       C  North    962     43    Bob  January      Q1
# 15 2023-01-16       D  South    933     65  Alice  January      Q1
# 16 2023-01-17       A   East    537     60   John  January      Q1
# 17 2023-01-18       B   West    481     79   Mary  January      Q1
# 18 2023-01-19       C  North    388     33    Bob  January      Q1
# 19 2023-01-20       D  South    236     35  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     709.0    NaN    NaN    NaN
# North      NaN    NaN  431.0    NaN
# South      NaN    NaN    NaN  782.0
# West       NaN  458.0    NaN    NaN

# %%
pivot2=pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product',aggfunc='median')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     709.0    NaN    NaN    NaN  58.0   NaN   NaN   NaN
# North      NaN    NaN  431.0    NaN   NaN   NaN  34.0   NaN
# South      NaN    NaN    NaN  782.0   NaN   NaN   NaN  44.0
# West       NaN  458.0    NaN    NaN   NaN  72.0   NaN   NaN

# %% [markdown]
# Cross Tabs

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
