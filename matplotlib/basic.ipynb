# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib Basics

# %%
x=np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title('Hello')
plt.xlabel('number')
plt.ylabel("square")
# Out:
# Text(0, 0.5, 'square')

# %% [markdown]
# Subplot

# %%
plt.subplot(2,2,1 )
plt.plot(x,y)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3 )
plt.plot(y,x)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)

# %%
plt.subplot(6,6,1)
# Out:
# <Axes: >

# %% [markdown]
# Object Oriented Way

# %%
fig=plt.figure()
axis1=fig.add_axes([0.1,0.1,0.8,0.8])
axis1.plot(x,y)
axis1=fig.add_axes([0.1,0.1,0.3,0.3])
axis1.plot(x,y)

# %% [markdown]
# Types of Plots

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([10.,  5., 12., 11.,  9., 10.,  9.,  8., 12., 14.]),
#  array([ 31., 127., 223., 319., 415., 511., 607., 703., 799., 895., 991.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22dc3fed6d0>,
#   <matplotlib.lines.Line2D at 0x22dc3fedf90>],
#  'caps': [<matplotlib.lines.Line2D at 0x22dc3fee890>,
#   <matplotlib.lines.Line2D at 0x22dc3fef190>],
#  'boxes': [<matplotlib.lines.Line2D at 0x22dc3fece10>],
#  'medians': [<matplotlib.lines.Line2D at 0x22dc3fefa50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22dc3ff81d0>],
#  'means': []}

# %% [markdown]
# Saving you plots

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig('basicplot.png')

# %% [markdown]
# Working With Image

# %%
import matplotlib.image as mpimage

# %%
img=mpimage.imread(r'C:\Users\Acer\OneDrive\Desktop\Python_Core_Concepts\matplotlib\Screenshot 2026-02-19 122611.png')
img
# Out:
# array([[[0.17254902, 0.17254902, 0.17254902, 1.        ],
#         [0.99607843, 0.7921569 , 0.01568628, 1.        ],
#         [1.        , 0.79607844, 0.01568628, 1.        ],
#         ...,
#         [0.18039216, 0.18039216, 0.18039216, 1.        ],
#         [0.18431373, 0.18431373, 0.18431373, 1.        ],
#         [0.19215687, 0.19215687, 0.19215687, 1.        ]],
#
#        [[0.17254902, 0.17254902, 0.17254902, 1.        ],
#         [1.        , 0.79607844, 0.01568628, 1.        ],
#         [1.        , 0.79607844, 0.01568628, 1.        ],
#         ...,
#         [0.18039216, 0.18039216, 0.18039216, 1.        ],
#         [0.18431373, 0.18431373, 0.18431373, 1.        ],
#         [0.1882353 , 0.1882353 , 0.1882353 , 1.        ]],
#
#        [[0.17254902, 0.17254902, 0.17254902, 1.        ],
#         [1.        , 0.79607844, 0.01568628, 1.        ],
#         [1.        , 0.79607844, 0.01568628, 1.        ],
#         ...,
#         [0.18039216, 0.18039216, 0.18039216, 1.        ],
#         [0.18431373, 0.18431373, 0.18431373, 1.        ],
#         [0.1882353 , 0.1882353 , 0.1882353 , 1.        ]],
#
#        ...,
#
#        [[0.18431373, 0.18431373, 0.18431373, 1.        ],
#         [0.18039216, 0.18039216, 0.18039216, 1.        ],
#         [0.18039216, 0.18039216, 0.18039216, 1.        ],
#         ...,
#         [0.18431373, 0.18431373, 0.18431373, 1.        ],
#         [0.1882353 , 0.1882353 , 0.1882353 , 1.        ],
#         [0.19215687, 0.19215687, 0.19215687, 1.        ]],
#
#        [[0.1882353 , 0.1882353 , 0.1882353 , 1.        ],
#         [0.18431373, 0.18431373, 0.18431373, 1.        ],
#         [0.18431373, 0.18431373, 0.18431373, 1.        ],
#         ...,
#         [0.1882353 , 0.1882353 , 0.1882353 , 1.        ],
#         [0.19215687, 0.19215687, 0.19215687, 1.        ],
#         [0.19607843, 0.19607843, 0.19607843, 1.        ]],
#
#        [[0.19215687, 0.19215687, 0.19215687, 1.        ],
#         [0.19215687, 0.19215687, 0.19215687, 1.        ],
#         [0.19215687, 0.19215687, 0.19215687, 1.        ],
#         ...,
#         [0.19215687, 0.19215687, 0.19215687, 1.        ],
#         [0.19607843, 0.19607843, 0.19607843, 1.        ],
#         [0.19607843, 0.19607843, 0.19607843, 1.        ]]],
#       shape=(671, 949, 4), dtype=float32)

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(948.5), np.float64(670.5), np.float64(-0.5))

# %%
cropped_img=img[50:200,100:300]
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %% [markdown]
# Designing

# %%
plt.plot(x,y,color='red')

# %%
xaxis = np.linspace(0,5,11)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
